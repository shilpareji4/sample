# %%
from fpdf import FPDF
from PIL import Image
import io
class PDF(FPDF):
    
    def footer(self):
        self.set_y(-15)
        self.set_font('Arial', 'I', 8)
        self.cell(0, 10, f'Page {self.page_no()}', 0, 0, 'C')

    def add_table(self, headers, data):
        # Page dimensions
        '''
        page_width = self.w - 2 * self.l_margin

        This line calculates the width of the printable area of the page by subtracting 
        twice the left margin (self.l_margin) from the total width of the page (self.w)
        '''
        page_width = self.w - 2 * self.l_margin
        print("page_width",page_width)
        
        # Calculate column widths based on the number of columns in the data
        #calculating the no.of columns of table
        num_columns = len(data[0])
        print("num_columns",num_columns)
        col_width = [page_width / num_columns] * num_columns

        print("col_width",col_width)
        
        # Header
        
        '''
        This line draws a cell in the PDF document with the width corresponding to the
        width of the header text, a height of 10 units, containing the header text (header), 
        and with a border 
        '''
        # for header in headers:
        self.cell(pdf.w-20, 10, headers[0], 1)
         
        self.ln()

        # Data
        for row in data:
            for item in row:
                self.cell(col_width[row.index(item)], 10, str(item), 1)
            self.ln()
        pdf.ln(20)
        
        
    def load_image(self):
         page_width = self.w - 2 * self.l_margin
         image_width =18
         x_coordinate = page_width - image_width - 10  # Adjust 10 as per your requirement for margin
         pdf.image('./oceanai.png', 
         x=x_coordinate, y=None, w=image_width, h=0, type='PNG')
   
 
                

    def test_pdf(self):
        # Initialize PDF object
        
       
        pdf.set_font("Arial", size=8)
        left_margin = 10  # Adjust this value according to your requirement
        top_margin = 10   # Adjust this value according to your requirement
        right_margin = 10 # Adjust this value according to your requirement
        
        # pdf.set_margins(left_margin, top_margin, right_margin)
        # Define column width and row height
        # col_width = pdf.w / 3.25
        col_width = pdf.w / 7.5
        spacing =20
   
        # spacing = 33
        
        row_height = pdf.font_size
        
    

        # Extracting data from item_data
        item_data = {
            'pdf_vessel_info_dict': [15, {'Vessel': 'Alpha', 'Local_End_Time': '2024-11-22 18:23:54', 'IMO_No': 'string', 'Total_Running_Hour': 'string', 'Cylinder_Oil_type': 'string', 'Normal_service_load_in_percentage_of_MCR': 'string', 'Scrubber': 'string', 'Position': 'string', 'ME_Cyllinder_Oil_Consumption': 'string', 'Me_Running_Hour_Since_Last_Check': 'string', 'Inspected_by_Rank': 'string', 'Fuel_Sulphur_percentage': 'string'}],
            'pdf_recomm_before_after_cleaning': [15, [[1, '*', '*', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscosity to attain correct viscosity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '*', '1) Increase the Feed rate\n2) Check correct cylinder oil feed rate.\n3) Optimize the scavange air temperature to avoid moisture carry over to cylinder space.'], [2, '1) Adjust the Cylinder Oil Feed rate\n2) Carry out Drain oil analysis (On board or send ashore)\n3) Adjust feed rate to obtain optimum residual BN', '1) Check Fuel injectors for leakage\n2) Check for carbon deposits', '*', '*', '*', '*'], [3, '1) Adjust the Cylinder Oil Feed rate\n2) Carry out Drain oil analysis (On board or send ashore)\n3) Adjust feed rate to obtain optimum residual BN', '*', '*', '*', '*', '*'], [4, '1) Adjust the Cylinder Oil Feed rate\n2) Carry out Drain oil analysis (On board or send ashore)\n3) Adjust feed rate to obtain optimum residual BN', '1) Check Fuel injectors for leakage\n2) Check for carbon deposits', '*', '*', '*', '*'], [5, 'DUPLICATE of cylinder1_Before_cleaning', 'DUPLICATE of cylinder1_Before_cleaning', 'DUPLICATE of cylinder1_Before_cleaning', 'DUPLICATE of cylinder1_Before_cleaning', 'DUPLICATE of cylinder1_Before_cleaning', '*'], [6, '*', '*', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscosity to attain correct viscosity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '*', 'Erroneous Image'], [7, '*', '*', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscosity to attain correct viscosity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '*', 'Erroneous Image'], [8, '1) Adjust the Cylinder Oil Feed rate\n2) Carry out Drain oil analysis (On board or send ashore)\n3) Adjust feed rate to obtain optimum residual BN', '*', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscosity to attain correct viscosity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '*', 'Erroneous Image'], [9, '*', '*', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscosity to attain correct viscosity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '*', '*'], [10, '*', '*', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscosity to attain correct viscosity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '*', 'DUPLICATE of cylinder9_Before_cleaning'], [11, '*', '*', '*', '*', '*', '*'], [12, 'Erroneous Image', 'Erroneous Image', 'Erroneous Image', 'Erroneous Image', 'Erroneous Image', '*'], [13, '*', '1) Check Fuel injectors for leakage\n2) Check for carbon deposits', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscosity to attain correct viscosity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '*', '*'], [14, 'DUPLICATE of cylinder11_After_cleaning', 'DUPLICATE of cylinder11_After_cleaning', 'DUPLICATE of cylinder11_After_cleaning', 'DUPLICATE of cylinder11_After_cleaning', 'DUPLICATE of cylinder11_After_cleaning', '*'], [15, '*', '*', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscosity to attain correct viscosity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '1) Replace Piston Rings\n2) Check for Carbon deposits in the ring groove\n3) Check vertical ring clearance\n4) Check for Partial sticking\n5) Check for Poor sealing between the ring and the ring groove floor.\n6) Check for Clover-leafing \n7) Check for Ring end chamfers.\n8) Check for too large ring-edge radii.\n9) Check for Continual striking against wear ridges, or other irregularities in the cylinder wall.', 'DUPLICATE of cylinder11_Before_cleaning']]], 
            'pdf_recomm_crown_liner': [15, [[1, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: check for leakage from fuel valve\n3) If Lube oil: check for leakage from the exhaust valve.\n4) If water: check for leakage from Cylinder head, Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [2, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: check for leakage from fuel valve\n3) If Lube oil: check for leakage from the exhaust valve.\n4) If water: check for leakage from Cylinder head, Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [3, 'Erroneous Image', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [4, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: check for leakage from fuel valve\n3) If Lube oil: check for leakage from the exhaust valve.\n4) If water: check for leakage from Cylinder head, Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [5, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: check for leakage from fuel valve\n3) If Lube oil: check for leakage from the exhaust valve.\n4) If water: check for leakage from Cylinder head, Exhaust valve, Injector pockets, crack in Liner.', '*'], [6, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: check for leakage from fuel valve\n3) If Lube oil: check for leakage from the exhaust valve.\n4) If water: check for leakage from Cylinder head, Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [7, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: check for leakage from fuel valve\n3) If Lube oil: check for leakage from the exhaust valve.\n4) If water: check for leakage from Cylinder head, Exhaust valve, Injector pockets, crack in Liner.', '*'], [8, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: check for leakage from fuel valve\n3) If Lube oil: check for leakage from the exhaust valve.\n4) If water: check for leakage from Cylinder head, Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [9, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: check for leakage from fuel valve\n3) If Lube oil: check for leakage from the exhaust valve.\n4) If water: check for leakage from Cylinder head, Exhaust valve, Injector pockets, crack in Liner.', '*'], [10, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: check for leakage from fuel valve\n3) If Lube oil: check for leakage from the exhaust valve.\n4) If water: check for leakage from Cylinder head, Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [11, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: check for leakage from fuel valve\n3) If Lube oil: check for leakage from the exhaust valve.\n4) If water: check for leakage from Cylinder head, Exhaust valve, Injector pockets, crack in Liner.', '*'], [12, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: check for leakage from fuel valve\n3) If Lube oil: check for leakage from the exhaust valve.\n4) If water: check for leakage from Cylinder head, Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [13, 'Erroneous Image', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [14, 'Erroneous Image', '*'], [15, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: check for leakage from fuel valve\n3) If Lube oil: check for leakage from the exhaust valve.\n4) If water: check for leakage from Cylinder head, Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage']]], 
            'pdf_images': ['image1.png','image2.png','image2.png','image3.png'], 
            'pdf_plot': ['oceanai.png']
        }

        pdf_recomm_before_after_cleaning = item_data['pdf_recomm_before_after_cleaning'][1]
        pdf_recomm_crown_liner = item_data['pdf_recomm_crown_liner'][1]
        print("pdf_recomm_crown_liner")
        print(pdf_recomm_crown_liner)

        data1 = [
            ['Cylinder No.', 'Too much Oil', 'Black Oil', 'Carbon', 'Scratch', 'Collapsed', 'Micro - Seizure']
        ]
        
        data2= [
            ['Cylinder No.', 'Crown', 'Liner']
        ]

        # Add column headings for data1 as the first row
        
        pdf.set_font('Arial','B', 8)
        pdf.multi_cell( pdf.w-20, 10, txt ="Possible Recommendation - Crown & Liner",border=1,ln=1, align="C")
        first_cell_width = 30
        col_width = pdf.w-20
        
        for heading_row in data1:
            col_width = (col_width-first_cell_width)/(len(heading_row)-1)
            cell_count = 0
            
            for heading_item in heading_row:
                # Convert heading_item to string if it's not already
                heading_item = str(heading_item)
                # Add multi cell for each heading item
                pdf.set_font('Arial', 'B', 8)
                if cell_count == 0:
                    # Add multi cell for each heading item
                    pdf.multi_cell(first_cell_width, 10, txt=heading_item, border=1, ln=3, max_line_height=pdf.font_size, align='C')
                else:
                    pdf.multi_cell(col_width, 10, txt=heading_item, border=1, ln=3, max_line_height=pdf.font_size, align='C')

                cell_count = cell_count+1
               
            # Add line break after each heading row
            pdf.ln(10)

        # Iterate over data rows for data1
        cylinder_numbers = []
        row_hgt = 98
        for row in pdf_recomm_before_after_cleaning:
            cylinder_numbers.append(row[0])
            cell_count = 0
            for item in row:               
                # Convert item to string if it's not already
                item = str(item)
                pdf.set_font('Arial','', 8)
                # Add multi cell for each item
                if cell_count == 0:
                    # Add multi cell for each heading item
                    pdf.multi_cell(first_cell_width, row_hgt, txt=item, border=1, ln=3, max_line_height=pdf.font_size, align='C')
                elif item =='*':
                    pdf.multi_cell(col_width, row_hgt, txt=item, border=1, ln=3, max_line_height=pdf.font_size+2, align='c')
                elif item == 'DUPLICATE of cylinder1_Before_cleaning':   
                    pdf.multi_cell(col_width, row_hgt, txt=item, border=1, ln=3, max_line_height=pdf.font_size+5, align='C') 
                elif item =='Erroneous Image':   
                    pdf.multi_cell(col_width, row_hgt, txt=item, border=1, ln=3, max_line_height=pdf.font_size+2, align='c') 
                else:
                    pdf.multi_cell(col_width, row_hgt, txt=item, border=1, ln=3, max_line_height=pdf.font_size+2, align='L')
                cell_count = cell_count+1
            # Add line break after each row
            pdf.ln(row_hgt)

        # Add a new line between the two tables
        pdf.ln(30)
        
        first_cell_width = 40
        col_width = pdf.w-20
        pdf.set_font('Arial','B', 8)
        pdf.multi_cell(col_width, 10, txt ="Possible Recommendation - Crown & Liner",border=1,ln=1, align="C")
        # Add column headings for data2 as the first row
        for heading_row in data2:            
            col_width = (col_width-first_cell_width)/(len(heading_row)-1)
            cell_count = 0
            for heading_item in heading_row:                
                # Convert heading_item to string if it's not already
                heading_item = str(heading_item)
                pdf.set_font('Arial','B', 8)
                if cell_count == 0:
                    # Add multi cell for each heading item
                    pdf.multi_cell(first_cell_width, 10, txt=heading_item, border=1, ln=3, max_line_height=pdf.font_size, align='C')
                else:                    
                    # Add multi cell for each heading item
                    pdf.multi_cell(col_width, 10, txt=heading_item, border=1, ln=3, max_line_height=pdf.font_size, align='C')
                cell_count = cell_count+1
            # Add line break after each heading row
            pdf.ln(10)
      
        # Iterate over data rows for data2
        for row in pdf_recomm_crown_liner:
            cell_count = 0
            for item in row:
                # Convert item to string if it's not already
                item = str(item)
                pdf.set_font('Arial','', 8)
                if cell_count == 0:
                    # Add multi cell for each item
                    pdf.multi_cell(first_cell_width, row_height*spacing, txt=item, border=1, ln=3, max_line_height=pdf.font_size, align='L')
                else:
                    if item == "Erroneous Image":
                        # Add multi cell for each item
                        pdf.multi_cell(col_width, row_height*spacing, txt=item, border=1, ln=3,max_line_height=pdf.font_size+4, align='C')
                    elif item == "*":
                        pdf.multi_cell(col_width, row_height*spacing, txt=item, border=1, ln=3,max_line_height=pdf.font_size+4, align='C')  
                    else:
                        # Add multi cell for each item
                        pdf.multi_cell(col_width, row_height*spacing, txt=item, border=1, ln=3,max_line_height=pdf.font_size+4, align='L')
                cell_count = cell_count+1
            # Add line break after each row
            pdf.ln(row_height * spacing)
            
        return cylinder_numbers
        
        
   
    def load_img(self, c_no):
        image_files = ['image1.png', 'image2.png', 'image3.png', 'image4.png']
        col_width = (pdf.w-20)/2
        header_text = 'Cylinder No'
        # pdf.multi_cell(col_width, 5, txt = header_text,border=1,ln=3, align="C")
        # pdf.multi_cell(col_width, 5, txt = header_text,border=1,ln=3, align="C")
        

        # Set the fixed header text outside the loop
        margin = 10
        cell_width = (self.w - 3 * margin) / 2  # Adjusted to accommodate right margin

        # # Calculate the maximum dimensions for the images to fit within the cell
        max_image_size = min(cell_width, (self.h - margin * 2 - 10) / 2)  # Adjusted height to fit within the margin

        # # pdf.ln(289)

        # header_text = 'Cylinder No'
        # # Add header for the table
        # pdf.set_font('Arial', '', 20)
        # # pdf.rect(margin, pdf.get_y(), cell_width * 26 + margin, 10)  # Draw a border around the content above the table
        # header_x = margin + (cell_width - pdf.get_string_width(header_text)) / 2

        # pdf.set_xy(header_x, pdf.get_y() + 2)  # Adjust y position to center the text vertically
        # pdf.set_font("Arial", 'B', size=8)
        # pdf.multi_cell(10,5,header_x)
        # pdf.cell(cell_width, 10, header_text, ln=False)  # Print the header text for the first column
        # pdf.cell(cell_width, 10, header_text, ln=True)  # Print the header text for the second column

        for cylinder_number in range(1, c_no + 1):
            # Counter for images added per row
            images_in_row = 0
            # Counter for images added per page
            images_per_page = 0

            # pdf.ln(1)

            for i, image_file in enumerate(image_files, start=1):
                # Add a new page if four images are already added
                if images_per_page == 4:
                    pdf.add_page()
                 
                    images_per_page = 0

                # Add a new line for every two images (two images per row)
                if images_in_row == 2:
                    pdf.ln(110)  # Add space between rows
                    images_in_row = 0

                # Calculate position for the image
                x = margin + images_in_row * (cell_width + margin)
                y = pdf.get_y()

        #         # Check if there is enough space for the image, otherwise add a new page
                if y + max_image_size > pdf.h:
                    pdf.add_page()
                    y = margin
                    images_per_page = 0

                # Draw the table border
                # pdf.rect(x - margin, y + 10, cell_width + 2 * margin, max_image_size + 10)
                pdf.rect(10, y+10, 140, 100)
                pdf.rect(150, y+10, 140, 100)

                # Add dynamic text based on the image index
                dynamic_text = "Cylinder No: " + str(cylinder_number) + ' - '
                if i == 1:
                    dynamic_text += 'Before Cleaning - Piston Rings'
                elif i == 2:
                    dynamic_text += 'After Cleaning - Piston Rings'
                elif i == 3:
                    dynamic_text += 'Crown - Crown'
                elif i == 4:
                    dynamic_text += 'Liner - Liner'

                # Add dynamic text above the image
                pdf.set_font("Arial", '', size=10)
                # pdf.set_xy(x, y)

                pdf.cell(140, 10, dynamic_text, align='C', ln=False,border=1)

                # Add image with calculated dimensions
                pdf.image(image_file, x=x+20, y=y + 10, w=100, h=100)

                # Increment counters
                images_in_row += 1
                images_per_page += 1
            pdf.ln(110)


pdf = PDF(format='A3')
pdf.add_page()
pdf.set_font('Arial','U',16)
pdf.cell(0,13,'Scavenge Inspection Report',0,0,'C')
pdf.load_image()
pdf.ln(20)
pdf.set_font('Arial','',10)
pdf.multi_cell(0,5,"This document has been created through an automated process utilizing advanced computer vision and artificial intelligence technology. The images provided by the crew were carefully analyzed using a state-of-the-art AI model that has been specifically trained to identify various types of faults such as  Carbon deposits, Excessive oil, Black Oil, Scratches, Collapsed , Micro -Seizure in Piston Ring, Oil Leakage in Crown and Cloverleafing in Liner area.")
pdf.ln(20)
pdf.set_font('Arial','U',12)
pdf.cell(0,5,'Vessel Info',0,0,'C')
pdf.ln(20)
#data
data_new={'pdf_vessel_info_dict': [15, {'Vessel': 'Alpha', 'Local_End_Time': '2024-11-22 18:23:54', 'IMO_No': 'string', 'Total_Running_Hour': 'string', 'Cylinder_Oil_type': 'string', 'Normal_service_load_in_percentage_of_MCR': 'string', 'Scrubber': 'string', 'Position': 'string', 'ME_Cyllinder_Oil_Consumption': 'string', 'Me_Running_Hour_Since_Last_Check': 'string', 'Inspected_by_Rank': 'string', 'Fuel_Sulphur_percentage': 'string'}], 
'pdf_recomm_before_after_cleaning': [15, [[1, '*', '*', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscocity to attain correct viscocity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '*', '1) Increase the Feed rate\n2) Check correct cylinder oil feed rate.\n3) Optimize the scavange air temperature to avoid moisture carry over to cylinder space.'], [2, '1) Adjust the Cylinder Oil Feed rate\n2) Carry out Drain oil analysis (On board or send ashore)\n3) Adjust feed rate to obtain optimum residual BN', '1) Check Fuel injectors for leakage\n2) Check for carbon deposits', '*', '*', '*', '*'], [3, '1) Adjust the Cylinder Oil Feed rate\n2) Carry out Drain oil analysis (On board or send ashore)\n3) Adjust feed rate to obtain optimum residual BN', '*', '*', '*', '*', '*'], [4, '1) Adjust the Cylinder Oil Feed rate\n2) Carry out Drain oil analysis (On board or send ashore)\n3) Adjust feed rate to obtain optimum residual BN', '1) Check Fuel injectors for leakage\n2) Check for carbon deposits', '*', '*', '*', '*'], [5, 'DUPLICATE of cylinder1_Before_cleaning', 'DUPLICATE of cylinder1_Before_cleaning', 'DUPLICATE of cylinder1_Before_cleaning', 'DUPLICATE of cylinder1_Before_cleaning', 'DUPLICATE of cylinder1_Before_cleaning', '*'], [6, '*', '*', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscocity to attain correct viscocity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '*', 'Erroneous Image'], [7, '*', '*', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscocity to attain correct viscocity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '*', 'Erroneous Image'], [8, '1) Adjust the Cylinder Oil Feed rate\n2) Carry out Drain oil analysis (On board or send ashore)\n3) Adjust feed rate to obtain optimum residual BN', '*', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscocity to attain correct viscocity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '*', 'Erroneous Image'], [9, '*', '*', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscocity to attain correct viscocity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '*', '*'], [10, '*', '*', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscocity to attain correct viscocity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '*', 'DUPLICATE of cylinder9_Before_cleaning'], [11, '*', '*', '*', '*', '*', '*'], [12, 'Erroneous Image', 'Erroneous Image', 'Erroneous Image', 'Erroneous Image', 'Erroneous Image', '*'], [13, '*', '1) Check Fuel injectors for leakage\n2) Check for carbon deposits', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscocity to attain correct viscocity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '*', '*'], [14, 'DUPLICATE of cylinder11_After_cleaning', 'DUPLICATE of cylinder11_After_cleaning', 'DUPLICATE of cylinder11_After_cleaning', 'DUPLICATE of cylinder11_After_cleaning', 'DUPLICATE of cylinder11_After_cleaning', '*'], [15, '*', '*', "1) Replace or Overhaul fuel injector to avoid improper combustion\n2) Adjust fuel temperature/viscocity to attain correct viscocity as per Maker's recommendation\n3) Check the condition of piston rings free movement (Gas sealing)\n4) Adjust the Cylinder Oil Feed rate to avoid over lubrication to avoid formation of carbon deposits", '*', '1) Replace Piston Rings\n2) Check for Carbon deposits in the ring groove\n3) Check vertical ring clearance\n4) Check for Partial sticking\n5) Check for Poor sealing between the ring and the ring groove floor.\n6) Check for Clover-leafing \n7) Check for Ring end chamfers.\n8) Check for too large ring-edge radii.\n9) Check for Continual striking against wear ridges, or other irregularities in the cylinder wall.', 'DUPLICATE of cylinder11_Before_cleaning']]], 
'pdf_recomm_crown_liner': [15, [[1, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: ckeck for leakage from fuel valve\n3) If Lube oil: check for leakae from the exhaust valve.\n4) If water: check for leakage from Cylinder head,Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [2, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: ckeck for leakage from fuel valve\n3) If Lube oil: check for leakae from the exhaust valve.\n4) If water: check for leakage from Cylinder head,Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [3, 'Erroneous Image', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [4, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: ckeck for leakage from fuel valve\n3) If Lube oil: check for leakae from the exhaust valve.\n4) If water: check for leakage from Cylinder head,Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [5, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: ckeck for leakage from fuel valve\n3) If Lube oil: check for leakae from the exhaust valve.\n4) If water: check for leakage from Cylinder head,Exhaust valve, Injector pockets, crack in Liner.', '*'], [6, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: ckeck for leakage from fuel valve\n3) If Lube oil: check for leakae from the exhaust valve.\n4) If water: check for leakage from Cylinder head,Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [7, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: ckeck for leakage from fuel valve\n3) If Lube oil: check for leakae from the exhaust valve.\n4) If water: check for leakage from Cylinder head,Exhaust valve, Injector pockets, crack in Liner.', '*'], [8, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: ckeck for leakage from fuel valve\n3) If Lube oil: check for leakae from the exhaust valve.\n4) If water: check for leakage from Cylinder head,Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [9, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: ckeck for leakage from fuel valve\n3) If Lube oil: check for leakae from the exhaust valve.\n4) If water: check for leakage from Cylinder head,Exhaust valve, Injector pockets, crack in Liner.', '*'], [10, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: ckeck for leakage from fuel valve\n3) If Lube oil: check for leakae from the exhaust valve.\n4) If water: check for leakage from Cylinder head,Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [11, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: ckeck for leakage from fuel valve\n3) If Lube oil: check for leakae from the exhaust valve.\n4) If water: check for leakage from Cylinder head,Exhaust valve, Injector pockets, crack in Liner.', '*'], [12, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: ckeck for leakage from fuel valve\n3) If Lube oil: check for leakae from the exhaust valve.\n4) If water: check for leakage from Cylinder head,Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [13, 'Erroneous Image', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage'], [14, 'Erroneous Image', '*'], [15, '1) Check if the leakage is fuel oil, lube oil or water\n2) If fuel oil: ckeck for leakage from fuel valve\n3) If Lube oil: check for leakae from the exhaust valve.\n4) If water: check for leakage from Cylinder head,Exhaust valve, Injector pockets, crack in Liner.', '1) Check for even supply of Cylinder oil from all the quills\n2) Check correct cylinder oil feed rate\n3) Check for moisture content leading to oil film breakage']]], 
'pdf_images': ['image1.png','image2.png','image3.png','image1.png4'], 
'pdf_plot':['oceanai.png']}


images=data_new.get('pdf_images', [])[1]
print(images)




print(data_new['pdf_vessel_info_dict'][0])
vessel_info_dict = data_new.get('pdf_vessel_info_dict', [])[1]


for key, value in vessel_info_dict.items():
    if key=='Vessel':
        vessel_name=value
    elif key=='IMO_No':
        imo=value
    elif key=='Local_End_Time':
        Local_End_Time=value
    elif key=='Total_Running_Hour':
        Total_Running_Hour=value
    elif key=='Cylinder_Oil_type':
        Cylinder_Oil_type=value
    elif key=='Normal_service_load_in_percentage_of_MCR':
        Normal_service_load_in_percentage_of_MCR=value
    elif key=='Scrubber':
        Scrubber=value
    elif key=='Me_Running_Hour_Since_Last_Check':
        Me_Running_Hour_Since_Last_Check=value
    elif key=='Position':
        Position=value
    elif key=='ME_Cyllinder_Oil_Consumption':
        ME_Cyllinder_Oil_Consumption=value
    elif key=='Inspected_by_Rank':
        Inspected_by_Rank=value
    elif key=='Fuel_Sulphur_percentage':
        Fuel_Sulphur_percentage=value
pdf.set_font('Arial', 'B', 8)  
pdf.cell(20, 8, 'Vessel:', 0, 0, 'L')

pdf.set_font('Arial', '', 8)  
pdf.cell(30, 8, vessel_name, 0, 0)

pdf.set_font('Arial', 'B', 8) 
pdf.cell(20, 8, 'IMO No:', 0, 0)

pdf.set_font('Arial', '', 8)  
pdf.cell(30, 8, imo, 0, 0)

pdf.set_font('Arial', 'B', 8)  
pdf.cell(30, 8, 'Local End Date:', 0, 0, 'C')

pdf.set_font('Arial', '', 8)  
pdf.cell(30, 8, Local_End_Time, 0, 0)

pdf.set_font('Arial','',8)
pdf.ln(20)
headers = ['General Data', '','','']
data = [
    ['Total Running Hour:',Total_Running_Hour ,'Position:',Position],
    ['Cylinder Oil type:',Cylinder_Oil_type, 'ME Cylinder Oil consumption:',ME_Cyllinder_Oil_Consumption],
    ['Normal service load in % of MCR:',Normal_service_load_in_percentage_of_MCR, 'Inspected by (Rank):',Inspected_by_Rank],
    ['Scrubber:',Scrubber, 'Fuel Sulphur %:',Fuel_Sulphur_percentage],
    ['ME Running Hour Since Last Check:', Me_Running_Hour_Since_Last_Check,'','']
    
    
]


pdf.add_table(headers, data)
c_no=pdf.test_pdf()
c=len(c_no)
pdf.ln(500)
pdf.load_img(c)
pdf.output(f'./testnew.pdf','F')
# Out:
# C:\Users\shilpa.reji\AppData\Local\Temp\ipykernel_14244\3806950320.py:300: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font('Arial','U',16)
# C:\Users\shilpa.reji\AppData\Local\Temp\ipykernel_14244\3806950320.py:301: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=0 use new_x=XPos.RIGHT, new_y=YPos.TOP.
#   pdf.cell(0,13,'Scavenge Inspection Report',0,0,'C')
# C:\Users\shilpa.reji\AppData\Local\Temp\ipykernel_14244\3806950320.py:54: DeprecationWarning: "type" parameter is deprecated since v2.2.0, unused and will soon be removed
#   pdf.image('./oceanai.png',
# C:\Users\shilpa.reji\AppData\Local\Temp\ipykernel_14244\3806950320.py:304: DeprecationWarning: Substituting font arial by core font helvetica - This is deprecated since v2.7.8, and will soon be removed
#   pdf.set_font('Arial','',10)
# ...
